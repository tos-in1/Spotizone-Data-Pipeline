# %% [markdown]
# ### Catalog Setup

# %%
# %sql

CREATE CATALOG IF NOT EXISTS `spotizone`;
USE CATALOG `spotizone`;

# %% [markdown]
# #### Schema Setup

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS spotizone.bronze; 
CREATE SCHEMA IF NOT EXISTS spotizone.silver;
CREATE SCHEMA IF NOT EXISTS spotizone.gold;
